# %%
import sympy
from phasor.utilities.ipynb.displays import *
from phasor.utilities.ipynb.ipy_sympy import *
import scipy.linalg


import numpy.testing as np_test
import declarative

from test_SVD import SVD_gen_check, gen_rand_unitary
from phasor.system import DAG_algorithm
from phasor.system import SRE_matrix_algorithms
from phasor.system import scisparse_algorithm

import timeit

asavefig.org_subfolder = 'plots'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Sympy version:  1.0

# %%
from functools import reduce
def SVD_compare_error(
    N = 10,
    length = 10,
    solver =  DAG_algorithm,
    N_in = None,
    N_out = None,
):
    U = gen_rand_unitary(N = N, length = length)
    V = gen_rand_unitary(N = N, length = length)

    seq = dict()
    req = dict()
    edge_map = dict()
    S_diags = []
    for idx in range(N):
        s_diag = 10**(-5 + 10 * np.random.random(length))
        edge_map[idx, idx] = s_diag
        S_diags.append(s_diag)
        seq[idx] = set([idx])
        req[idx] = set([idx])
    S = seq, req, edge_map
    condition = reduce(np.maximum, S_diags) / reduce(np.minimum, S_diags)

    M = SRE_matrix_algorithms.matrix_mult_sre(
        SRE_matrix_algorithms.matrix_mult_sre(U, S), V
    )

    SRE_matrix_algorithms.check_sre(M)
    sparsity = SRE_matrix_algorithms.SRE_count_sparsity(M)
    print("SPARSITY FRAC: ", sparsity)

    if N_in is None:
        inputs_set = set(range(N))
    else:
        inputs_set = set(range(N-N_in, N))
    if N_out is None:
        outputs_set = set(range(N))
    else:
        mid = N_out // 2
        outputs_set = set(range(0, mid)) | set(range(N-(N_out - mid), N))

    Mseq, Mreq, Medge_map = SRE_matrix_algorithms.copy_sre(M)
    print(solver)
    time_start = timeit.default_timer()
    sbunch = solver.inverse_solve_inplace(
        seq = Mseq,
        req = Mreq,
        edge_map = Medge_map,
        inputs_set = inputs_set,
        outputs_set = outputs_set,
        verbose = True,
        negative = False,
    )
    time_end = timeit.default_timer()
    b = declarative.Bunch( 
        time = time_end - time_start,
        length = length,
    )
    b.update(sparsity)
    return b

# %%
mats = []
for N in [10, 30, 100, 300]:
    for length in [10, 100, 1000, 10000]:
        for inst in range(3):
            r = SVD_compare_error(
                N = N,
                length = length,
                N_in = 10,
                N_out = 10
            )
            mats.append(r)
# Out:
# SPARSITY FRAC:  {'density_lin': 2.9, 'Nedges': 29, 'Nnodes': 10, 'density_sq': 0.29}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 10
# BADGUY STAGE, REMAINING 10
# SPARSITY FRAC:  {'density_lin': 1.7, 'Nedges': 17, 'Nnodes': 10, 'density_sq': 0.17}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 5
# BADGUY STAGE, REMAINING 5
# SPARSITY FRAC:  {'density_lin': 1.9, 'Nedges': 19, 'Nnodes': 10, 'density_sq': 0.19}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 7
# BADGUY STAGE, REMAINING 7
# SPARSITY FRAC:  {'density_lin': 2.0, 'Nedges': 20, 'Nnodes': 10, 'density_sq': 0.2}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 6
# BADGUY STAGE, REMAINING 6
# SPARSITY FRAC:  {'density_lin': 1.9, 'Nedges': 19, 'Nnodes': 10, 'density_sq': 0.19}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 7
# BADGUY STAGE, REMAINING 7
# SPARSITY FRAC:  {'density_lin': 3.6, 'Nedges': 36, 'Nnodes': 10, 'density_sq': 0.36}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 10
# BADGUY STAGE, REMAINING 10
# SPARSITY FRAC:  {'density_lin': 3.5, 'Nedges': 35, 'Nnodes': 10, 'density_sq': 0.35}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 8
# BADGUY STAGE, REMAINING 8
# SPARSITY FRAC:  {'density_lin': 2.3, 'Nedges': 23, 'Nnodes': 10, 'density_sq': 0.23}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 8
# BADGUY STAGE, REMAINING 8
# SPARSITY FRAC:  {'density_lin': 2.6, 'Nedges': 26, 'Nnodes': 10, 'density_sq': 0.26}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 8
# BADGUY STAGE, REMAINING 8
# SPARSITY FRAC:  {'density_lin': 2.3, 'Nedges': 23, 'Nnodes': 10, 'density_sq': 0.23}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 8
# BADGUY STAGE, REMAINING 8
# SPARSITY FRAC:  {'density_lin': 4.1, 'Nedges': 41, 'Nnodes': 10, 'density_sq': 0.41}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 9
# BADGUY STAGE, REMAINING 9
# SPARSITY FRAC:  {'density_lin': 5.6, 'Nedges': 56, 'Nnodes': 10, 'density_sq': 0.56}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 10
# TRIVIAL STAGE, REMAINING 9
# BADGUY STAGE, REMAINING 9
# SPARSITY FRAC:  {'density_lin': 2.466666666666667, 'Nedges': 74, 'Nnodes': 30, 'density_sq': 0.08222222222222222}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 16
# TRIVIAL STAGE, REMAINING 15
# BADGUY STAGE, REMAINING 15
# SPARSITY FRAC:  {'density_lin': 2.966666666666667, 'Nedges': 89, 'Nnodes': 30, 'density_sq': 0.09888888888888889}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 16
# TRIVIAL STAGE, REMAINING 15
# BADGUY STAGE, REMAINING 15
# SPARSITY FRAC:  {'density_lin': 3.4, 'Nedges': 102, 'Nnodes': 30, 'density_sq': 0.11333333333333333}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 26
# TRIVIAL STAGE, REMAINING 26
# BADGUY STAGE, REMAINING 26
# SPARSITY FRAC:  {'density_lin': 2.6666666666666665, 'Nedges': 80, 'Nnodes': 30, 'density_sq': 0.08888888888888889}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 18
# TRIVIAL STAGE, REMAINING 15
# BADGUY STAGE, REMAINING 15
# SPARSITY FRAC:  {'density_lin': 2.9, 'Nedges': 87, 'Nnodes': 30, 'density_sq': 0.09666666666666666}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 22
# TRIVIAL STAGE, REMAINING 21
# BADGUY STAGE, REMAINING 21
# SPARSITY FRAC:  {'density_lin': 3.1, 'Nedges': 93, 'Nnodes': 30, 'density_sq': 0.10333333333333333}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 22
# TRIVIAL STAGE, REMAINING 20
# BADGUY STAGE, REMAINING 20
# SPARSITY FRAC:  {'density_lin': 4.0, 'Nedges': 120, 'Nnodes': 30, 'density_sq': 0.13333333333333333}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 25
# TRIVIAL STAGE, REMAINING 25
# BADGUY STAGE, REMAINING 25
# SPARSITY FRAC:  {'density_lin': 5.4, 'Nedges': 162, 'Nnodes': 30, 'density_sq': 0.18}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 25
# TRIVIAL STAGE, REMAINING 25
# BADGUY STAGE, REMAINING 25
# SPARSITY FRAC:  {'density_lin': 3.3, 'Nedges': 99, 'Nnodes': 30, 'density_sq': 0.11}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 23
# TRIVIAL STAGE, REMAINING 20
# BADGUY STAGE, REMAINING 20
# SPARSITY FRAC:  {'density_lin': 3.8333333333333335, 'Nedges': 115, 'Nnodes': 30, 'density_sq': 0.12777777777777777}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 21
# TRIVIAL STAGE, REMAINING 20
# BADGUY STAGE, REMAINING 20
# SPARSITY FRAC:  {'density_lin': 3.433333333333333, 'Nedges': 103, 'Nnodes': 30, 'density_sq': 0.11444444444444445}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 25
# TRIVIAL STAGE, REMAINING 25
# BADGUY STAGE, REMAINING 25
# SPARSITY FRAC:  {'density_lin': 3.1666666666666665, 'Nedges': 95, 'Nnodes': 30, 'density_sq': 0.10555555555555556}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 23
# TRIVIAL STAGE, REMAINING 22
# BADGUY STAGE, REMAINING 22
# SPARSITY FRAC:  {'density_lin': 3.39, 'Nedges': 339, 'Nnodes': 100, 'density_sq': 0.0339}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 33
# TRIVIAL STAGE, REMAINING 31
# BADGUY STAGE, REMAINING 31
# SPARSITY FRAC:  {'density_lin': 2.88, 'Nedges': 288, 'Nnodes': 100, 'density_sq': 0.0288}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 45
# TRIVIAL STAGE, REMAINING 44
# BADGUY STAGE, REMAINING 44
# SPARSITY FRAC:  {'density_lin': 3.15, 'Nedges': 315, 'Nnodes': 100, 'density_sq': 0.0315}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 35
# TRIVIAL STAGE, REMAINING 34
# BADGUY STAGE, REMAINING 34
# SPARSITY FRAC:  {'density_lin': 3.53, 'Nedges': 353, 'Nnodes': 100, 'density_sq': 0.0353}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 57
# TRIVIAL STAGE, REMAINING 55
# BADGUY STAGE, REMAINING 55
# SPARSITY FRAC:  {'density_lin': 2.7, 'Nedges': 270, 'Nnodes': 100, 'density_sq': 0.027}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 32
# TRIVIAL STAGE, REMAINING 29
# BADGUY STAGE, REMAINING 29
# SPARSITY FRAC:  {'density_lin': 3.06, 'Nedges': 306, 'Nnodes': 100, 'density_sq': 0.0306}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 26
# TRIVIAL STAGE, REMAINING 24
# BADGUY STAGE, REMAINING 24
# SPARSITY FRAC:  {'density_lin': 3.04, 'Nedges': 304, 'Nnodes': 100, 'density_sq': 0.0304}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 47
# TRIVIAL STAGE, REMAINING 47
# BADGUY STAGE, REMAINING 47
# SPARSITY FRAC:  {'density_lin': 3.22, 'Nedges': 322, 'Nnodes': 100, 'density_sq': 0.0322}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 23
# TRIVIAL STAGE, REMAINING 21
# BADGUY STAGE, REMAINING 21
# SPARSITY FRAC:  {'density_lin': 3.66, 'Nedges': 366, 'Nnodes': 100, 'density_sq': 0.0366}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 57
# TRIVIAL STAGE, REMAINING 55
# BADGUY STAGE, REMAINING 55
# SPARSITY FRAC:  {'density_lin': 3.4, 'Nedges': 340, 'Nnodes': 100, 'density_sq': 0.034}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 34
# TRIVIAL STAGE, REMAINING 33
# BADGUY STAGE, REMAINING 33
# SPARSITY FRAC:  {'density_lin': 3.0, 'Nedges': 300, 'Nnodes': 100, 'density_sq': 0.03}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 19
# TRIVIAL STAGE, REMAINING 17
# BADGUY STAGE, REMAINING 17
# SPARSITY FRAC:  {'density_lin': 3.0, 'Nedges': 300, 'Nnodes': 100, 'density_sq': 0.03}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 11
# TRIVIAL STAGE, REMAINING 9
# BADGUY STAGE, REMAINING 9
# SPARSITY FRAC:  {'density_lin': 3.73, 'Nedges': 1119, 'Nnodes': 300, 'density_sq': 0.012433333333333333}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 123
# TRIVIAL STAGE, REMAINING 122
# BADGUY STAGE, REMAINING 122
# SPARSITY FRAC:  {'density_lin': 3.51, 'Nedges': 1053, 'Nnodes': 300, 'density_sq': 0.0117}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 148
# TRIVIAL STAGE, REMAINING 148
# BADGUY STAGE, REMAINING 148
# SPARSITY FRAC:  {'density_lin': 3.47, 'Nedges': 1041, 'Nnodes': 300, 'density_sq': 0.011566666666666666}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 137
# TRIVIAL STAGE, REMAINING 136
# BADGUY STAGE, REMAINING 136
# SPARSITY FRAC:  {'density_lin': 3.15, 'Nedges': 945, 'Nnodes': 300, 'density_sq': 0.0105}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 87
# TRIVIAL STAGE, REMAINING 85
# BADGUY STAGE, REMAINING 85
# SPARSITY FRAC:  {'density_lin': 3.816666666666667, 'Nedges': 1145, 'Nnodes': 300, 'density_sq': 0.012722222222222222}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 152
# TRIVIAL STAGE, REMAINING 152
# BADGUY STAGE, REMAINING 152
# SPARSITY FRAC:  {'density_lin': 3.3266666666666667, 'Nedges': 998, 'Nnodes': 300, 'density_sq': 0.01108888888888889}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 112
# TRIVIAL STAGE, REMAINING 111
# BADGUY STAGE, REMAINING 111
# SPARSITY FRAC:  {'density_lin': 4.113333333333333, 'Nedges': 1234, 'Nnodes': 300, 'density_sq': 0.013711111111111111}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 172
# TRIVIAL STAGE, REMAINING 172
# BADGUY STAGE, REMAINING 172
# SPARSITY FRAC:  {'density_lin': 3.3866666666666667, 'Nedges': 1016, 'Nnodes': 300, 'density_sq': 0.011288888888888888}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 36
# TRIVIAL STAGE, REMAINING 34
# BADGUY STAGE, REMAINING 34
# SPARSITY FRAC:  {'density_lin': 3.9833333333333334, 'Nedges': 1195, 'Nnodes': 300, 'density_sq': 0.013277777777777777}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 96
# TRIVIAL STAGE, REMAINING 93
# BADGUY STAGE, REMAINING 93
# SPARSITY FRAC:  {'density_lin': 3.816666666666667, 'Nedges': 1145, 'Nnodes': 300, 'density_sq': 0.012722222222222222}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 142
# TRIVIAL STAGE, REMAINING 137
# BADGUY STAGE, REMAINING 137
# SPARSITY FRAC:  {'density_lin': 3.216666666666667, 'Nedges': 965, 'Nnodes': 300, 'density_sq': 0.010722222222222222}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 73
# TRIVIAL STAGE, REMAINING 71
# BADGUY STAGE, REMAINING 71
# SPARSITY FRAC:  {'density_lin': 4.29, 'Nedges': 1287, 'Nnodes': 300, 'density_sq': 0.0143}
# <module 'phasor.system.DAG_algorithm' from '/home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py'>
# TRIVIAL STAGE, REMAINING 164
# TRIVIAL STAGE, REMAINING 161
# BADGUY STAGE, REMAINING 161
# /home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py:645: RuntimeWarning: invalid value encountered in true_divide
#   u_mod_edge = edge + norm_orig * edge / abs(edge)
# /home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py:365: RuntimeWarning: invalid value encountered in greater
#   rel_r_to_c = np.asarray(np.count_nonzero(normr > normc))
# /home/mcculler/local/home_sync/projects/phasor/phasor/system/DAG_algorithm.py:387: RuntimeWarning: invalid value encountered in greater_equal
#   bignodes_r = np.array(rvec) >= 1./(len(req[node]))**.5

# %%
axB = mplfigB(Nrows=1)
color_by_len = {
    10 : 'blue',
    100 : 'green',
    1000 : 'purple',
    10000 : 'red',
}
for r in mats:
    axB.ax0.scatter(
        r.Nnodes, 
        r.time,
        color = color_by_len[r.length],
    )
axB.ax0.set_xscale('log')
axB.ax0.set_yscale('log')
axB.ax0.set_xlim(9, 400)
axB.save('timing_by_nodes_direct')
# Out:
# figure: plots/timing_by_nodes_direct.png
# [[file:plots/timing_by_nodes_direct.png]]
# <img src="1497206794/../plots/timing_by_nodes_direct.png?1497206794">

# %%
axB = mplfigB(Nrows=1)
for r in mats:
    axB.ax0.scatter(
        r.Nnodes, 
        r.time / r.Nnodes,
        color = color_by_len[r.length],
    )
axB.ax0.set_xscale('log')
axB.ax0.set_yscale('log')
axB.ax0.set_xlim(9, 400)
axB.save('timing_by_nodes_relsq2')
# Out:
# figure: plots/timing_by_nodes_relsq2.png
# [[file:plots/timing_by_nodes_relsq2.png]]
# <img src="1497206852/../plots/timing_by_nodes_relsq2.png?1497206852">

# %%
axB = mplfigB(Nrows=1)
for r in mats:
    axB.ax0.scatter(
        r.Nnodes, 
        r.time / r.length,
        color = color_by_len[r.length],
    )
axB.ax0.set_xscale('log')
axB.ax0.set_yscale('log')
axB.ax0.set_xlim(9, 400)
axB.save('timing_by_nodes_rellength')
# Out:
# figure: plots/timing_by_nodes_rellength.png
# [[file:plots/timing_by_nodes_rellength.png]]
# <img src="1497206855/../plots/timing_by_nodes_rellength.png?1497206855">
